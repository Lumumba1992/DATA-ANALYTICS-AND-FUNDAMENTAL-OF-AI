# %% [markdown]
# ### **Reading Data From the Internet**

# %%
import pandas as pd
import numpy as np

# %%
url = "http://rtgodwin.com/data/mars.csv"

df = pd.read_csv(url)
df.head()
# Out:
#                 name  gender   ethnicity  age  income marital.status  \
# 0    Joshua Willmann    male  indigenous   77   86197        married
# 1      Davien Kaplan    male       other   30  118743         single
# 2  Zahraaa el-Farrah  female      arabic   52   62074        married
# 3   Daija Mccullough  female       black   46   64050       divorced
# 4      Kasmira Hicks  female       black   40  113806        married
#
#    years.education occupation  years.on.earth birth.world          IQ  \
# 0               12   employed              77       earth   81.275274
# 1               24   employed              26       earth  133.419160
# 2               11   employed              13       earth  102.890578
# 3               17   employed              16       earth   97.040212
# 4               12   employed              20       earth   93.942351
#
#      height
# 0  1.562685
# 1  1.945074
# 2  1.617343
# 3  1.582241
# 4  1.563654
